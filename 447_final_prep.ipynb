# %% [markdown]
# # 447 Fa19 final prep -- exam: 10:30--12:20p Thu Dec 12
#
# ## instructions (these will be repeated on the exam sheet -- **please read them carefully**)
#
# **Important:** write your name and student number at the top of every page you submit.
#
# You are permitted to refer to both sides of one (1) sheet of 8.5in x 11in paper for notes; **no other references (including other people) are permitted**.
#
# Each part of each problem is worth 2 points:  1 point for participation, and 1 point for correctness; therefore, **it is in your interest to attempt every subproblem**.
#
# Make use of scratch paper -- write your final solution clearly and legibly; **draw a box around every answer**.

# %% [markdown]
# # *pre-midterm*

# %% [markdown]
# ## homework problems
#
# ### hw1 problems 2, 3, 4
#
# ### hw2 problems 1, 2
#
# ### hw3 problems 1(a--d), 2, 3(a--c)
#
# Regarding problem 2:  you will not be expected to draw phase portraits by hand, but you will be expected to interpret phase portraits that are provided.

# %% [markdown]
# ## problem (from Fa18 midterm exam)
#
# Consider a system that consists of two coupled 2nd-order systems
# $$\ddot{q}_1 + 2 \dot{q}_1 + 3 q_1 = 4 u,\ \ddot{q}_2 + 5 \dot{q}_2 + 6 q_2 = 7 q_1$$
# with input $u$ and output $y = 8 q_2$.
#
#
# ### subproblem a.
#
# Determine an expression for the transfer function $G_{yu}(s)$ as a rational function of $s$ (i.e. ratio of polynomials in the variable $s$).
#
#
# ### subproblem b.
#
# With $x = (q_1,\dot{q}_1,q_2,\dot{q}_2)$, determine $A,B$ such that
# $$ \dot{x} = A x + B u. $$

# %% [markdown]
# ## problem (from Fa18 midterm exam)
#
# Consider the scalar nonlinear differential equation
#
# $$ (NL)\quad \dot{x} = f(x,u) = - r x \left(1 - \frac{x}{c} + u\right) $$
#
# that models dynamics of a population $x > 0$ with rate parameter $r > 0$, carrying capacity $c > 0$, and input $u$.  Note that if the input is constant, $u(t) = u_e > 0$, the population levels $0$ (zero) and $x_e = c(1 + u_e)$ are equilibria for $(NL)$.
#
#
# ### subproblem a.
#
# Graph $f(x,u_e)$ on an interval containing both equilibria, and indicate whether each equilibrium is stable.
#
#
# ### subproblem b.
#
# Now $(NL)$ is linearized around the positive equilibrium $x_e$ to obtain
#
# $$ (L)\quad \delta\dot{x} = a\,\delta x + b\,\delta u $$
#
# where $a,b > 0$ are such that $x \approx x_e + \delta x$ when $u = u_e + \delta u$.
#
# (**Note:**  you **don't** need to determine the value of the variables $a,b$ to solve this problem.)
#
# Suppose proportional feedback $\delta u = -k\,\delta x$ is applied to $(L)$.  Use the Routh-Hurwitz stability criterion to determine the greatest lower bound on $k > 0$ that ensures $(L)$ is asymptotically stable in terms of $a,b$.

# %% [markdown]
# ## problem (from Fa18 hw4)
#
# A simplified nonlinear DE model for the forward velocity $v > 0$ of a car on a horizontal road is given by
# $$ (NL)\quad \dot{v} = f(v,u) = u (1-(v-1)^2). $$
#
# **Assume the input is a positive constant (i.e. $u(t) = u_e > 0$).**
#
# ### subproblem a.
# Determine the equilibrium speed $v_e$ of $(NL)$.
#
# ### subproblem b.
# Sketch the  graph of $f(v,u_e)$ vs. $v$.  How does $u_e$ affect the graph?
#
# ### subproblem c.
# Determine whether the equilibrium from (a.) is stable.
#
# ### subproblem d.
# Linearize the nonlinear system at the equilibrium found in (a.) to obtain a linear time-invariant DE
#
# $$ (L)\quad \delta\dot{v} = a\,\delta v + b\,\delta u $$
#
# where $v \approx v_e + \delta v$ and $u \approx u_e + \delta u$ (i.e. determine the scalars $a$, $b$).
#
# ### subproblem e.
# Determine whether the origin of $(L)$ is stable.

# %% [markdown]
# ## problem (from Fa18 hw4)
#
# Consider the scalar DE
# $$T \dot{y} + y = u.$$
#
# **Assume the input is constant ($u(t) = u_e$) and the parameter $T$ is positive ($T > 0$).**
#
# ### subproblem a.
# Express $y(t)$ in terms of $t$, $T$, $y(0)$, $u_e$.
#
# ### subproblem b.
# Show that $y_e = u_e$ is the only equilibrium for the system.
#
# ### subproblem c.
# Show that the equilibrium $y_e = u_e$ is stable.

# %% [markdown]
# ## problem (from Fa18 hw4)
#
# ### subproblem a.
#
# Show that matrix multiplication does not generally *commute*, i.e. find $A,B\in\mathbb{R}^{n\times n}$ for which $A\,B \neq B\,A$.  (*Hint:  you should be able to find an example when $n = 2$.*)
#
# ### subproblem b.
#
# Show that every square matrix commutes with its matrix exponential, i.e. $A\, e^A = e^AA$ for all $A\in\mathbb{R}^{n\times n}$.
#
# ### subproblem c.
#
# Given an invertible matrix $T\in\mathbb{R}^{n\times n}$, show that $e^{T A T^{-1}} = T e^A T^{-1}$.
#
# ### subproblem d.
#
# If $\lambda\in\mathbb{C}$ is an eigenvalue of $A$ with corresponding eigenvector $v\in\mathbb{C}^{n}$, show that $e^{\lambda}$ is an eigenvalue of $e^A$ and determine a corresponding eigenvector.

# %% [markdown]
# # *post-midterm*

# %% [markdown]
# ## homework problems
#
# ### hw6 problems 1(a,b,e,g), 2(a,b,c,d)
#
# ### hw7 problems 1(a,d,e)
#
# ### hw8 problems 1(a,b,c,d,e), 2(a,b,c,d,e,f)
#
# Regarding problem 2:  you will not be expected to draw Bode plots by hand, but you will be expected to interpret Bode plots that are provided.

# %% [markdown]
# ## problem (from Fa18 final exam)
#
# Suppose the LTI process
# $ \dot{x} = A x + B u,\ y = C x + D u $
# is controlled with an observer
# $$ \dot{\widehat{x}} = A\widehat{x} + B u + L(y - \widehat{y}),\ \widehat{y} = C\widehat{x} + D u,\ u = -K\widehat{x}. $$
#
# Express the transfer function $\widehat{G}_{uy}$ from $y$ to $u$ through the observer in terms of $A, B, C, D, K, L$.

# %% [markdown]
# ## problem (from Fa18 final exam)
#
# Consider $L(s) = P(s) C(s) = 2 / (s + 1)^3$, the *(open-)loop transfer function* for a control system; the *Bode plot* of $L$ is below.  Determine whether the closed-loop system is stable using the *Nyquist stability criterion*.
#
# ![](http://faculty.washington.edu/sburden/447/447-final-exam-bode-plot.png)

# %% [markdown]
# ## problem (from Fa18 final exam)
#
# Determine how many states are added when a process is controlled with proportional-integral-derivative (PID) feedback, i.e. determine how much larger the degree of the closed-loop system's characteristic polynomial is relative to the process's characteristic polynomial; assume the process transfer function is *strictly proper*.

# %% [markdown]
# ## problem (from Fa18 final exam)
#
# Consider $L(s) = P(s) C(s)$, the *(open-)loop transfer function* for a control system; the *Nyquist plot* of $L$ is below.  Determine the controller's *gain margin*, that is, the smallest value for $k > 0$ such that $k\, C(s)$ no longer stabilizes $P(s)$ through negative feedback.
#
# ![](http://faculty.washington.edu/sburden/447/447-final-exam-nyquist-plot.png)

# %% [markdown]
# ## problem (from Fa18 final exam)
#
# Your boss asks you to tune the controller $C(s)$ so that the closed-loop system below is insensitive to both the input disturbance $v$ and output disturbance $w$; specifically, you are given the following performance specifications on the transfer functions from $v$ to $u$ and from $w$ to $y$:
#
# $$\forall s\in\mathbb{C} : |G_{uv}(s)| \le 0.1,\ |G_{yw}(s)| \le 0.1. $$
#
# Prove that it is impossible to simultaneously satisfy both performance specifications by changing $C(s)$.
#
# ![](http://faculty.washington.edu/sburden/447/447-final-exam-block-diagram.png)

# %% [markdown]
# ## problem (from Fa18 hw6)
#
# Recall that the output of an LTI system
#
# $$ \dot{x} = A x + B u,\ y = C x + D u $$
#
# given by the convolution equation is
#
# $$ y(t) = C e^{At} x(0) + \int_0^t C e^{A(t-\tau)} B u(\tau) d\tau + D u(t). $$
#
# a. Evaluate the integral in this expression for $u(t) = e^{s t}$; you can assume $s\in\mathbb{C}$ is not an eigenvalue of $A$, i.e. $s\not\in\lambda(A)$.
#
# *Hint:  if you use properties of the matrix exponential, you can simplify this computation to the point where you can reuse the *step response* calculation from lecture.*
#
# b. Take the limit as time goes to infinity to obtain an expression for the system's transfer function $G(s)$ in terms of $A, B, C, D$; you can assume the system is asymptotically stable so that all eigenvalues of $A$ have negative real part, i.e. $\operatorname{Re}\lambda(A) < 0$.
#
# **Now consider the following op-amp circuit.**
#
# ![op-amp](http://faculty.uw.edu/sburden/447/447-hw6-op-amp.png)
#
# Assuming feedback gains are sufficiently large to ensure the input voltages are approximately equal (see [AMv2 Ch 4.3] for a discussion of when this is a valid approximation), Kirchoff's current law yields
#
# $$ \frac{v_1 - v_2}{R_1} - C_1 \dot{v}_2 = 0,\ C_2 \dot{v}_3 + C_1 \dot{v}_2 + \frac{v_3}{R_2} = 0. $$
#
# Choosing the state vector $x = (v_2,v_3)$ and regarding $u = v_1$ as the input and $y = v_3$ as the output yields the LTI system
#
# $$ \dot{x} = \left[\begin{matrix} -\frac{1}{R_1C_1} & 0 \\ \frac{1}{R_1 C_2} & -\frac{1}{R_2 C_2} \end{matrix} x \right] + \left[\begin{matrix} \frac{1}{R_1C_1} \\ -\frac{1}{R_1 C_2} \end{matrix} \right] u,\ y = \left[\begin{matrix} 0 & 1 \end{matrix}\right] x. $$
#
# c. Use (b.) to determine an expression for the circuit's *frequency response*, i.e. compute the transfer function and evaluate it at $s =j\omega$.
#
# d. Use a computation tool to plot the *gain* (i.e. magnitude) and *phase* (i.e. angle) of the frequency response from (c.).  (What kind of filter is this?)

# %% [markdown]
# ## problem (from Fa18 hw6/7)
#
# Consider the nonlinear pendulum model
#
# **Note to Sam:  change sign back to stable pendulum!**
#
# $$ \ m \ell^2 \ddot{\theta} = m g \ell \sin\theta - \gamma\dot{\theta} + \ell u \cos\theta. $$
#
# a. With $x = (\theta,\dot{\theta})$, determine $f(x,u)$ such that $\dot{x} = f(x,u)$.
#
# b. Linearize the nonlinear system from (a.) about the equilibrium $x_e = (\theta_e,\dot{\theta}_e) = (0,0)$ by computing Jacobian derivatives, and determine the stability type of the equilibrium.
#
# c. Verify that the state-space LTI system system you obtain in (b.) is the same as the one you obtain by transcribing the following 2nd-order linear DE to state-space form:
#
# $$ m \ell^2 \ddot{\theta} = m g \ell \theta - \gamma\dot{\theta} + \ell u. $$
#
# d. Determine controller gains that place the eigenvalues of the closed-loop system at $-\sigma \pm j\omega$ where $\sigma,\omega > 0$.
#
# e. Determine observer gains that place the eigenvalues of the error system at $-\zeta$ where $\zeta > 0$.

# %% [markdown]
# ## problem (from Fa18 hw7)
#
# Consider the $n$--th order DE
#
# $$ \frac{d^n}{dt^n} y + a_1 \frac{d^{n-1}}{dt^{n-1}} y + \cdots + a_n y = b_1 \frac{d^{n-1}}{dt^{n-1}} u + b_2 \frac{d^{n-2}}{dt^{n-2}} u + \cdots + b_n u. $$
#
# a. If $\rho$ is a root of the polynomial $s^n + a_1 s^{n-1}  + \cdots + a_n$, show that $y(t) = e^{\rho t}$ is a solution of the DE with $u(t) = 0$.
#
# b. If $\zeta$ is a root of the polynomial $b_1 s^{n-1} + b_2 s^{n-2} + \cdots + b_n$, show that there is a solution of the DE with $u(t) = e^{\zeta t}$, which is nonzero, where the output is identically zero, i.e. $y(t) = 0$.
