# %% [markdown]
# # HW6
#
# ## due 5p Fri Nov 8 2019 for +2 bonus points
#
# ## automatic extension to midnight (11:59p) Sun Nov 10
#
# You are welcome (and encouraged) to work with others, but ***each individual must create and submit their own writeup***.
#
# You are welcome to use analytical and numerical computational tools; if you do, include the **commented** sourcecode in your writeup.
#
# You are welcome to consult websites, textbooks, and other materials; if you do, include a full citation in your writeup.
#
# **Important:** before you do any work in the Colaboratory notebook, click "File -> Save a copy in Drive ..." and rename the file to something memorable.
#
# **Also important:** To produce a .pdf for submission to Canvas, click "File -> Print" (or press Ctrl/Cmd + P), and choose "Save to PDF" or "Microsoft Print to PDF" as your printer.

# %% [markdown]
# # 0. your name
#
# ***Note:*** these subproblems are each worth 1 (one) point -- ***please provide answers!!!***
#
# a. How many hours did you spend on this homework?
#
# b. Which days of the week did you work on the homework, and for how long? (Monday, Tuesday, Wednesday, Thursday, Friday)
#
# c. Which office hours are you able to attend?  Which office hours did you attend (if any)?  (Prof Burden -- Tue, Thu; TA Momona -- Wed; TA Nivii -- Friday)
#
# d. Is there anything else we can do to support your engagement and learning in the course?
#
# ***Important:*** the Teaching Assistants are conducting a mid-quarter assessment -- use the following forms to provide your anonymous feedback.
#
# e. [TA Nivii](https://docs.google.com/forms/d/e/1FAIpQLSdYwBOvoQotH2hLbpeqegOCI2yKdSc-AOtCi_KXf6EIQGyQtw/viewform)
#
# f. [TA Momona](https://docs.google.com/forms/d/e/1FAIpQLScQZiwvoDCSuHwLXcaGorh1JTkRDJMKqfiWK6p4ut6ukYMMgQ/viewform)

# %% [markdown]
# # 1. spring-mass-damper a deux redux
# Consider the following spring-mass-damper system from hw3:
# ![spring-mass](http://faculty.uw.edu/sburden/447/447-hw1-spring-mass.png)
# The input to this system is the sinusoidal motion of the end of rightmost spring.
# Applying Newton's laws to determine the forces acting on both masses, we find two coupled second-order DE that model the system's dynamics:
#
# $$ m\ddot{q}_1 = - c \dot{q}_1 - k q_1 + k (q_2 - q_1), $$
#
# $$ m\ddot{q}_2 = - c \dot{q}_2 + k (u - q_2) - k (q_2 - q_1). $$
#
# Defining $x = (q_1, \dot{q}_1, q_2, \dot{q}_2)$, we can transcribe the two coupled second-order DE obtained above into one first-order DE in matrix/vector form $\dot{x} = A x + B u$:
#
# $$ \dot{x} = \left[ \begin{matrix} \dot{q}_1 \\ \ddot{q}_1 \\ \dot{q_2} \\ \ddot{q_2} \end{matrix} \right] = \left[ \begin{matrix} 0 & 1 & 0 & 0 \\ -\frac{2k}{m} & -\frac{c}{m}& +\frac{k}{m}  & 0 \\ 0 & 0 & 0 & 1 \\ +\frac{k}{m} & 0 & - \frac{2k}{m} & -\frac{c}{m} \end{matrix} \right] \left[ \begin{matrix} {q}_1 \\ \dot{q}_1 \\ {q_2} \\ \dot{q_2} \end{matrix} \right] + \left[ \begin{matrix} 0 \\ 0 \\ 0 \\ \frac{k}{m} \end{matrix} \right] u = A x + B u. $$
#
# ***Purpose:*** apply analytical and computational tools to see connections between modeling concepts we learned in the first half of the class.
#
# ## change-of-coordinates
#
# Consider the alternative choice of state vector $z = (p_1,\dot{p}_1,p_2,\dot{p}_2)$ where $p_1 = \frac{1}{2}(q_1 + q_2)$, $p_2 = \frac{1}{2} (q_1 - q_2)$.
#
# a. Determine the matrix $T\in\mathbb{R}^{4\times 4}$ such that $z = T x$.
#
# b. Determine the matrix $T^{-1}\in\mathbb{R}^{4\times 4}$ such that $x = T^{-1} z$.  (***Hint:*** solve the equations $p_1 = \frac{1}{2}(q_1 + q_2)$, $p_2 = \frac{1}{2} (q_1 - q_2)$ for $q_1$ and $q_2$ in terms of $p_1$ and $p_2$.)
#
# c. Compute $\widetilde{A} = T A T^{-1}$, $\widetilde{B} = T B$ and verify that $\dot{z} = \widetilde{A} z + \widetilde{B} u$ by comparing with the solution to problem (1b.) from homework 3.
#
# d. Verify that $A$ has the same eigenvalues as $\widetilde{A}$ using parameters $m = 250$, $k = 50$, $c = 10$.
#
# ***Bonus:*** verify that $A$ has the same eigenvalues as $\widetilde{A}$ symbolically (i.e. without using numerical values for the parameters).
#
# ***Takeaway:***  a linear system's dynamics can be represented using different choices of state variables (also termed ***coordinates***), which changes the
# $``A"$
# and
# $``B"$
# matrices.  However, the eigenvalues of the $A$'s -- hence, the system's stability properties -- aren't affected by the change-of-coordinates (also termed a ***similarity transform***).
#
# ## input/output response
#
# e. Determine the transfer function from $u$ to $q_1$ using the solution to problem (1a.) on homework 3.
#
# Use parameter values $m = 250$, $k = 50$, $c = 10$ in the remaining subproblems.
#
# f. Determine the roots of the characteristic polynomial of the transfer function from (e.), and verify that they are also the eigenvalues of the matrix $A$.
#
# g. Plot the position of the first mass in response to an
# input motion $u(t) = \sin(t) + 100\sin(\pi t)$ two ways:  first, by numerically simulating the state-space differential equation; second, by evaluating the transfer function derived in (e.).  Do the two plots agree?  (***Hint:*** the first plot will generally differ from the second plot due to the inclusion of the ***homogeneous*** response to the initial state.)
#
# h. Plot the steady-state amplitude of the motion of the first mass as a function of the frequency $\omega$ of a sinusoidal input $u(t) = \sin(\omega t)$ two ways:  first, by numerically simulating the state-space differential equation; second, using the transfer function derived in (e.).  Do the two plots agree?  (***Hint:*** the two plots should differ slightly since the numerical simulations only approximate the steady-state amplitude, whereas the transfer function computes it exactly.)
#
# ***Takeaway:*** both time- and frequency-domain representations of a given linear system each have advantages and disadvantages, but they can both be used to determine the system's stability and steady-state output (and should give the same answers!).

# %% [markdown]
# # 2. control of a nonlinear system
#
# Consider the model of a rigid rod of length $\ell$ attached to a point mass $m$ at one end and a rotational joint at the other end,
#
# $$ \ m \ell^2 \ddot{\theta} = m g \ell \sin\theta - \gamma\dot{\theta} + \tau, $$
#
# where
# $\gamma$ is a coefficient of friction for the rotational joint
# and
# $\tau$ is a torque applied by a motor attached to the rotational joint.
#
# a. With $x = (\theta,\dot{\theta})$ and $u = \tau$, determine $f(x,u)$ such that $\dot{x} = f(x,u)$.
#
# b. Linearize the nonlinear system from (a.) about the equilibrium $x_e = (\theta_e,\dot{\theta}_e) = (0,0)$ by computing Jacobian derivatives of $f$ with respect to $x$ and $u$.
#
# Use parameter values $m = 1$ kg, $\ell = 1$ m, $g = 9.81$ m/sec/sec, $\gamma = 1$ in the remaining subproblems.
#
# c. Determine whether the linear system from (b.) is stable when no control input is applied.
#
# d. Determine whether the linear system from (b.) is stable when proportional control $u = - k_P \theta$ is applied; you choose the value of $k_P > 0$.
#
# e. Verify your answers from (c.) and (d.) using numerical simulations and phase portraits; include plots of the phase portraits with representative trajectories in your writeup.
#
# f. Using numerical simulations, verify that your controller from (d.) also stabilizes the equilibrium in the nonlinear system, but only if the initial state is close enough to the equilibrium; include a plot of the phase portrait with representative trajectories in your writeup.
