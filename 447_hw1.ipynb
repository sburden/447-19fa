# %% [markdown]
# # HW1 due 12p (noon) Tue Oct 9
#
# You are welcome (and encouraged) to work with others, but each individual must submit their own writeup.
#
# You are welcome to use analytical and numerical computational tools; if you do, include the **commented** sourcecode in your submission (e.g. the .ipynb file).
#
# You are welcome to consult websites, textbooks, and other materials; if you do, include a full citation in your writeup (e.g. the .ipynb file).
#
#
# # 1. solution of DE
#
# **Assume $u(0)$ and $y(0),\dot{y}(0)$ are given scalars, i.e. $u(0),y(0),\dot{y}(0)\in\mathbb{R}$.**
#
# **Consider the differential equation (DE)**
# $$\dot{y} + a y = b u.$$
#
# a. Solve the DE (i.e. determine $y(t)$ for $t > 0$) when $u = 0$, $y(0) \neq 0$.
#
# b. Solve the DE when $u(t) = e^{s t}$, $y(0) = 0$.
#
# **Now consider DE'**
# $$\ddot{y} + 2\dot{y} + y = 2 \dot{u} + u.$$
#
# c. Solve DE' when $u = 0$, $y(0),\dot{y}(0) \neq 0$.
#
# d. Solve DE' when $u(t) = e^{s t}$, $y(0), \dot{y}(0) = 0$.

# %% [markdown]
# # 2. block diagrams
#
# Consider the following three block diagrams:
# ![block-diagrams](http://faculty.uw.edu/sburden/447/447-hw1-block-diagrams.png)
#
# For each (a., b., c.), apply *block diagram algebra* to verify the given expression for the transfer function $G_{yu}$ from $u$ to $y$.
#
# (What is meant by the phrase "*block diagram algebra*"?  You should substitute $u = e^{st}$, guess that $y(t) = G_{yu}(s) e^{st}$, and perform algebraic manipulations involving the other signals (represented by arrows) in the diagram to solve for $G_{yu}(s)$ in terms of $G_1(s)$ and $G_2(s)$.)

# %% [markdown]
# # 3. transfer functions
#
# **This problem will consider the following feedback block diagram:**
# ![spring-mass](http://faculty.uw.edu/sburden/447/447-hw1-feedback.png)
#
# a. Determine the transfer function $G_{yr}$ from the reference $r$ to output $y$.
#
# b. How does $G_{yr}$ change if the process gain increases by $10\%$?
#
# **Now consider the dynamics of the pupillary reflex, which can be approximated by a linear system with transfer function defined for all $s\in\mathbb{C}$ by
# $P(s) = \frac{0.2(1-0.1s)}{(1+0.1s)^3}$.
# Assume that the nerve system that controls the pupil opening implements a proportional controller with gain $k$ (i.e. $C(s) = k$).**
#
# c. Apply the Routh-Hurwitz stability criterion to determine the largest value for the gain $k$ that gives a stable closed-loop system.
#
# **Now consider the process $P(s) = \frac{b}{s^2 + a_1 s + a_2}$ and proportional-integral-derivative (PID) controller $C(s) = k_P + \frac{k_I}{s} + k_D s$.**
#
# d. Show that controller parameters
# $$k_P = \frac{(1 + 2\alpha\zeta)\omega_C^2 - a_2}{b},\ k_I = \frac{\alpha\omega_c^3}{b},\ k_D = \frac{(\alpha+2\zeta)\omega_c - a_1}{b}$$
# yield a transfer function from $r$ to $y$ with characteristic polynomial $a(s) = (s^2 + 2\zeta\omega_c s + \omega_c^2)(s + \alpha\omega_c)$.

# %% [markdown]
# # 4. discrete-time dynamics
# **Consider the *discrete-time* system
# $$ x[k+1] = A x[k] + B u[k],\ y[k] = C x[k], $$
# where
# $$ x = \left[ \begin{matrix} x_1 \\ x_2 \end{matrix} \right],\
# A = \left[ \begin{matrix} a_{11} & a_{12} \\ 0 & a_{22} \end{matrix} \right],\
# B = \left[ \begin{matrix} 0 \\ 1 \end{matrix} \right],\
# C = \left[ \begin{matrix} 1 & 0 \end{matrix} \right].  $$
# In this problem, you will explore properties of this system as a function of the parameters, initial state, and input.**
#
# a. Derive an expression for the output when $a_{12} = 0$ and $u = 0$.
#
# b.  Let $u(t) = \mu$ be constant, and determine $x_e$ such that $x_e = A x_e + B \mu$; the point $x_e$ is termed an *equilibrium*.
#
# c. Determine the eigenvalues of $A$.
#
# *d. Show that if $|a_{11}|, |a_{22}| < 1$ then all initial states converge to $x_e$ determined in (b.).
#
# e. Use your preferred computational tool to plot the output of the system in response to a unit step input from initial state $x[0] = 0$ with parameters $a_{11} = 0.5$, $a_{12} = 1$ and $a_{22} = 0.25$.
